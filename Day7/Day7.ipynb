# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split

# %%
d={'very good':5, 'very poor':1, 'average':3, 'poor':2, 'good':4}

# %%
data=pd.read_excel("std_details_s.xlsx")
data
# Out:
#   course_name course_id  attempted_id   cand_name       cand_email  marks  \
# 0        chem     A6025            90  20881A0562  dskjc@kjdsnc.cd    100
# 1          ml     A5720           456  20881A0593     dsjb@jdkfn.c     99
# 2     physics     A5645          4556  20881A05B1          fsv@d.j      0
# 3          ml     A5720           234  20881A05B1          fsv@d.j     50
# 4        chem     A6025            65  20881A05B1          fsv@d.j     34
# 5     physics     A5645          4556  20881A0562  dskjc@kjdsnc.cd     45
# 6     physics     A5645            23  20881A05B5     ekjwf@kjn.cd     67
# 7          ml     A5720           456  20881A05C1    jkvs@fdkv.dsf     23
# 8          ml     A5720           435  20881A0545         dfg@f.ef     94
# 9        chem     A6025           435  20881A05B2        gfsd@ds.d     75
#
#   grade     status
# 0    A+  very good
# 1     A  very good
# 2     F  very poor
# 3     B    average
# 4     C       poor
# 5     B    average
# ...

# %%
data['marks']=data['marks'].astype(float)
data['status']=data['status'].replace('very poor','1')
data['status']=data['status'].replace('poor','2')
data['status']=data['status'].replace('average','3')
data['status']=data['status'].replace('good','4')
data['status']=data['status'].replace('very good','5')
data['status']=data['status'].astype(float)
data
# Out:
#   course_name course_id  attempted_id   cand_name       cand_email  marks  \
# 0        chem     A6025            90  20881A0562  dskjc@kjdsnc.cd  100.0
# 1          ml     A5720           456  20881A0593     dsjb@jdkfn.c   99.0
# 2     physics     A5645          4556  20881A05B1          fsv@d.j    0.0
# 3          ml     A5720           234  20881A05B1          fsv@d.j   50.0
# 4        chem     A6025            65  20881A05B1          fsv@d.j   34.0
# 5     physics     A5645          4556  20881A0562  dskjc@kjdsnc.cd   45.0
# 6     physics     A5645            23  20881A05B5     ekjwf@kjn.cd   67.0
# 7          ml     A5720           456  20881A05C1    jkvs@fdkv.dsf   23.0
# 8          ml     A5720           435  20881A0545         dfg@f.ef   94.0
# 9        chem     A6025           435  20881A05B2        gfsd@ds.d   75.0
#
#   grade  status
# 0    A+     5.0
# 1     A     5.0
# 2     F     1.0
# 3     B     3.0
# 4     C     2.0
# 5     B     3.0
# 6    B+     4.0
# ...

# %%
x=data.iloc[:,5]
y=data.iloc[:,-1]
y
# Out:
# 0    5.0
# 1    5.0
# 2    1.0
# 3    3.0
# 4    2.0
# 5    3.0
# 6    4.0
# 7    1.0
# 8    5.0
# 9    4.0
# Name: status, dtype: float64

# %%
xtrain,xtest,ytrain,ytest=train_test_split(x,y)
xtrain=np.array(xtrain).reshape(-1,1)
ytrain=np.array(ytrain).reshape(-1,1)
xtest=np.array(xtest).reshape(-1,1)

# %%
log=LogisticRegression()
log.fit(xtrain,ytrain)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
res=log.predict(xtest)
res
# Out:
# array([4., 2., 5.])

# %%
ytest
# Out:
# 6    4.0
# 7    1.0
# 1    5.0
# Name: status, dtype: float64

# %% [markdown]
# # Image classification

# %%
from PIL import Image,ImageChops
from matplotlib import pyplot as plt

# %%
img=Image.open("spider.png")
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=332x368 at 0x7F9EB16746A0>

# %%
img.format
# Out:
# 'PNG'

# %%
img.size
# Out:
# (332, 368)

# %%
img.mode
# Out:
# 'RGBA'

# %%
img.resize((100,100))
# Out:
# <PIL.Image.Image image mode=RGBA size=100x100 at 0x7F9EB166A8E0>

# %%
r,g,b,a=img.split()

# %%
r
# Out:
# <PIL.Image.Image image mode=L size=332x368 at 0x7F9EAFDDA100>

# %%
g
# Out:
# <PIL.Image.Image image mode=L size=332x368 at 0x7F9EAFDDA130>

# %%
b
# Out:
# <PIL.Image.Image image mode=L size=332x368 at 0x7F9EAFDDA190>

# %%
plt.subplot(1,3,1)
plt.imshow(r)
plt.subplot(1,3,2)
plt.imshow(g)
plt.subplot(1,3,3)
plt.imshow(b)

# %%
rg=ImageChops.add(r,g)
rg
# Out:
# <PIL.Image.Image image mode=L size=332x368 at 0x7F9EAF33D3A0>

# %%
rg.convert('1')
# Out:
# <PIL.Image.Image image mode=1 size=332x368 at 0x7F9EAF90F760>

# %%
pip install pil
